# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 24 not upgraded.
# Need to get 9,599 kB of archives.
# After this operation, 29.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 fonts-nanum all 20180306-3 [9,599 kB]
# Fetched 9,599 kB in 1s (18.3 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='NanumBarunGothic')

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_word = pd.read_excel('/content/단어 긍정 부정.xlsx', index_col = None)
df_word
# Out:
#     word  word_test
# 0    아파트   0.048456
# 1     서울   0.013018
# 2     매매   0.010144
# 3     하락   0.009222
# 4     거래   0.007832
# ..   ...        ...
# 247  여전히   0.000261
# 248   중소   0.000258
# 249   조짐   0.000258
# 250  집주인   0.000258
# 251   입지   0.000255
#
# [252 rows x 2 columns]

# %%
df_word_top_50 = df_word[3:103]

# %%
df_word_dict = df_word.set_index('word')['word_test'].to_dict()
df_word_dict
# Out:
# {'아파트': 0.04845590602731107,
#  '서울': 0.01301762333887802,
#  '매매': 0.01014383482705742,
#  '하락': 0.009221668024597661,
#  '거래': 0.007832031624215075,
#  '상승': 0.007014598447519439,
#  '만에': 0.005793557639830332,
#  '강남': 0.005093630482284689,
#  '집값': 0.004751330339543391,
#  '부동산': 0.0003218643133239073,
#  '가격': 0.003772965006185801,
#  '주택': 0.003537952967885805,
#  '매수': 0.003154781166309725,
#  '규제': 0.003080701284671682,
#  '전세': 0.003067928891285813,
#  '시장': 0.00295297735081299,
#  '최고': 0.002822698938277122,
#  '재건축': 0.002789490715473862,
#  '전국': 0.002725628748544516,
#  '수도권': 0.002659212302937995,
#  '심리': 0.002401209956543434,
#  '분양': 0.002355229340354305,
#  '셋값': 0.002250495714590176,
#  '평균': 0.002064018771156485,
#  '승률': 0.002056355335124963,
#  '역대': 0.002051246377770614,
#  '대책': 0.001951621709360834,
#  '상승세': 0.00194906723068366,
#  '연속': 0.00194906723068366,
#  '최저': 0.001928631401266269,
#  '정부': 0.001872432870368444,
#  '최대': 0.001834115690210836,
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_word_dict)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
df_word_top_50_dict = df_word_top_50.set_index('word')['word_test'].to_dict()
df_word_top_50_dict
# Out:
# {'하락': 0.009221668024597661,
#  '거래': 0.007832031624215075,
#  '상승': 0.007014598447519439,
#  '만에': 0.005793557639830332,
#  '강남': 0.005093630482284689,
#  '집값': 0.004751330339543391,
#  '부동산': 0.004615942969653176,
#  '가격': 0.003772965006185801,
#  '주택': 0.003537952967885805,
#  '매수': 0.003154781166309725,
#  '규제': 0.003080701284671682,
#  '전세': 0.003067928891285813,
#  '시장': 0.00295297735081299,
#  '최고': 0.002822698938277122,
#  '재건축': 0.002789490715473862,
#  '전국': 0.002725628748544516,
#  '수도권': 0.002659212302937995,
#  '심리': 0.002401209956543434,
#  '분양': 0.002355229340354305,
#  '셋값': 0.002250495714590176,
#  '평균': 0.002064018771156485,
#  '승률': 0.002056355335124963,
#  '역대': 0.002051246377770614,
#  '대책': 0.001951621709360834,
#  '상승세': 0.00194906723068366,
#  '연속': 0.00194906723068366,
#  '최저': 0.001928631401266269,
#  '정부': 0.001872432870368444,
#  '최대': 0.001834115690210836,
#  '대출': 0.00182389777550214,
#  '매가': 0.001808570903439097,
#  '억원': 0.001783026116667359,
# ...

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_word_top_50_dict)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 35.0 MB/s eta 0:00:00
# ...

# %%
df_total = pd.read_excel('/content/drive/MyDrive/Colab Notebooks/data/total.xlsx', index_col = None)
df_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26536 entries, 0 to 26535
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     26536 non-null  object
#  1   name     26536 non-null  object
#  2   title    26536 non-null  object
#  3   content  26535 non-null  object
# dtypes: object(4)
# memory usage: 829.4+ KB

# %%
df_total.insert(1, 'year', pd.to_datetime(df_total['date']).dt.year)
df_total.head()
# Out:
#          date  year    name  \
# 0  2018-01-01  2018    연합뉴스
# 1  2018-01-01  2018    조선비즈
# 2  2018-01-01  2018    서울경제
# 3  2018-01-01  2018  파이낸셜뉴스
# 4  2018-01-01  2018   스포츠서울
#
#                                                title  \
# 0                    "집 파느니 증여한다"…잇단 규제에 주택 매매↓, 증여↑
# 1       [아파트 별곡]① 자산증식 욕망이 불패 신기루 만들어…주거대안 화두에 진화 거듭
# 2  [2018년 주목! 여기] 4청량리 역세권, 교통망·주거환경 개선 동시에...일대 ...
# 3                     서울 아파트 4.69% 오를 때 지방은 0.41% 하락
# 4                 [부동산 理實直告]아파트,관리비예치금과 장기수선충담금은 계륵?
#
#                                              content
# 0  주택 증여 작년 11월까지 8만 건 육박…역대 최대 전망2년 연속 100만 건 넘었...
# 1  대한민국은 아파트 공화국이다. 우리나라 집 10채 중 6채는 아파트다. 아파트에 열...
# 2  경강선 이어 올 8월 분당선 연장집창촌은 도심 랜드마크 변신중미주 전용 86.78㎡...
# 3  5년여만에 전세가격 내려.. 수도권 1.4% 올라 대조적               ...
# 4  [스포츠서울]일반적으로 부동산을 거래한다는 것은 매매계약을 말한다. 하지만 임대차계...

# %%
df_2020 = df_total[df_total['year'] == 2020]
df_2020.head()
# Out:
#              date  year     name                            title  \
# 11263  2020-01-01  2020    아시아경제             지난달(12월) 아파트 매매 실거래가
# 11264  2020-01-01  2020     서울경제   12·16대책 전 한달간 서울 아파트값 1.24% 상승
# 11265  2020-01-02  2020      SBS   서울 아파트값 뛰자 오피스텔 매매가도 2분기 연속 상승
# 11266  2020-01-02  2020  SBS Biz  아파트 매매값 상승폭 둔화…인기지역 전셋값은 ‘고공행진’
# 11267  2020-01-02  2020   한국경제TV  서울 아파트값 2주 연속 상승폭 축소…12·16대책 영향
#
#                                                  content
# 11263  작년 12월 아파트 매매 실거래가는 다음과 같다.서울지역의 아파트 매매가를 살펴보면...
# 11264  [서울경제] 12·16 대책 시행 전 한 달여 동안 서울 아파트 매매가격이 1.24...
# 11265  ▲ 위 사진은 기사 내용과 관련이 없습니다.서울 아파트값 상승의 영향으로 오피스텔 ...
# 11266  [앵커]작년 12.16 부동산 대책 영향으로 서울 아파트값 상승세가 한풀 꺾였는데요...
# 11267  정부의 고강도 부동산 규제인 12·16 부동산 대책 이후 서울 아파트 가격 상승폭이...

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5168 entries, 11263 to 16430
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     5168 non-null   object
#  1   year     5168 non-null   int64
#  2   name     5168 non-null   object
#  3   title    5168 non-null   object
#  4   content  5168 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 242.2+ KB

# %%
df_2020.reset_index(drop = True, inplace = True)
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5168 entries, 0 to 5167
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     5168 non-null   object
#  1   year     5168 non-null   int64
#  2   name     5168 non-null   object
#  3   title    5168 non-null   object
#  4   content  5168 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 202.0+ KB

# %%
from konlpy.tag import Komoran
komoran = Komoran()

df_2020['title_words'] = df_2020['title'].apply(lambda x: [word for word, pos in komoran.pos(x) if pos.startswith('N') | pos.startswith('V')])
df_2020_title_words = df_2020.explode('title_words')
df_word_count_2020 = df_2020_title_words['title_words'].value_counts().reset_index()
df_word_count_2020.columns = ['word', 'count']
df_word_count_2020
# Out:
# <ipython-input-75-d30d4f102cc3>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['title_words'] = df_2020['title'].apply(lambda x: [word for word, pos in komoran.pos(x) if pos.startswith('N') | pos.startswith('V')])
#      word  count
# 0     아파트   3671
# 1      서울   2240
# 2       값   1099
# 3       억    965
# 4      매매    964
# ...   ...    ...
# 3785   보호      1
# 3786   당정      1
# 3787   심층      1
# 3788  김현수      1
# 3789   한도      1
#
# [3790 rows x 2 columns]

# %%
import pandas as pd
import re
from collections import Counter
from konlpy.tag import Okt

okt = Okt()

# 특수 기호와 숫자를 제거하는 함수
def remove_special_char(text):
    return re.sub('[^ㄱ-ㅣ가-힣a-zA-Z]', '', text)

# 데이터프레임에서 텍스트 열을 형태소 분석하여 딕셔너리로 저장하는 함수
def count_words(text):
    text = remove_special_char(text) # 특수 기호와 숫자 제거
    morphs = okt.morphs(text)
    count_dict = Counter(morphs) # Counter 클래스 사용
    return count_dict

# 형태소 분석 결과를 저장할 리스트
morphs_list = []

# 데이터프레임의 각 행을 반복하며 형태소 분석을 수행
for index, row in df_2021.iterrows():
    text = row['title'] # 텍스트 데이터가 저장된 열의 이름에 맞게 수정하세요 # titie이나 conteant로 바꾸기
    morphs_dict = count_words(text)
    morphs_list.append(morphs_dict)

# 모든 단어의 빈도수를 합산한 딕셔너리 생성
total_count = Counter()
for morphs_dict in morphs_list:
    total_count.update(morphs_dict)

# 결과 출력하기
# for word, count in sorted(total_count.items(), key=lambda x: x, reverse=True):
#     if len(word) >= 1 and count >= 100: # word = 글자수  count=글자빈도수 설정
#         print(word, count)

# morphs_list를 데이터프레임으로 변환
df_morphs = pd.DataFrame(morphs_list)

# 각 단어의 총 빈도수 계산
total_count = df_morphs.sum(axis=0)

# 총 빈도수를 데이터프레임으로 변환
df_total_count_2021 = pd.DataFrame({'word': total_count.index, 'count': total_count.values})

# 빈도수가 100 이상인 단어만 추출
# df_result = df_total_count[df_total_count['count'] >= 100]

# # 결과 출력
# print(df_result)

# %%
import pandas as pd
from konlpy.tag import Okt
from tqdm import tqdm

# okt 객체 생성
okt = Okt()

# content 열에서 Null 값 제거
news_article = df_2020.dropna(subset=['content'])

# content 열의 모든 문장에 대해 형태소 분석을 수행하고, 그 결과를 'morphs' 열에 저장
news_article['morphs'] = news_article['content'].apply(lambda x: okt.morphs(str(x)))

# 단어 집합(vocabulary) 생성
vocabulary = {}
for i in tqdm(news_article['morphs']):
    for j in i:
        if j not in vocabulary:
            vocabulary[j] = 0
        vocabulary[j] += 1

# 빈도수가 높은 순으로 정렬된 단어 리스트 생성
word_list = sorted(vocabulary.items(), key=lambda x: x[1], reverse=True)

# 결과를 엑셀 파일로 저장(단어 포함)
result_df = pd.DataFrame(word_list, columns=['word', 'freq'])
result_df.to_excel('./2020년(단어 포함) 본문 단어 빈도수.xlsx', index=False)


# 결과를 엑셀 파일로 저장(단어 미포함)
word_list = sorted([(k, v) for k, v in vocabulary.items() if k not in ['서울', '아파트', '매매']], key=lambda x: x[1], reverse=True) # '서울', '아파트', '매매'를 제외한 vocabulary 딕셔너리에서 빈도수가 높은 순으로 정렬된 단어 리스트 생성
result_df = pd.DataFrame(word_list, columns=['word', 'freq'])
result_df.to_excel('./2020년(단어 미포함) 본문 단어 빈도수.xlsx', index=False)
# Out:
# 100%|██████████| 5168/5168 [00:01<00:00, 2603.16it/s]

# %%
df_2021 = pd.read_excel('/content/2021년(단어 포함) 본문 단어 빈도수.xlsx', index_col = None)
df_2021.head(10)
# Out:
#   word    freq
# 0    .  113539
# 1    이   78873
# 2    을   50099
# 3    (   45348
# 4    에   43961
# 5    가   43433
# 6    ,   41803
# 7    은   41003
# 8  아파트   39374
# 9    )   38301

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54729 entries, 0 to 54728
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   word    54724 non-null  object
#  1   freq    54729 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 855.3+ KB

# %%
df_2020['freq'] = df_2020['freq'].astype(str)
# Out:
# <ipython-input-40-0e92664b9333>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['freq'] = df_2020['freq'].astype(str)

# %%
import re

# 특수 기호 제거 및 2글자 이상인 단어만 남기기
df_2020['word'] = df_2020['word'].apply(lambda x: re.sub(r'[^\w\sㄱ-ㅎㅏ-ㅣ가-힣]', '', str(x))) # 특수 기호 제거
df_2020['word'] = df_2020['word'].apply(lambda x: re.findall(r'\b[ㄱ-ㅎㅏ-ㅣ가-힣]{2,}\b', x)[0] if len(re.findall(r'\b[ㄱ-ㅎㅏ-ㅣ가-힣]{2,}\b', x)) > 0 else '') # 2글자 이상인 단어만 남기기
df_2020
# Out:
# <ipython-input-42-e7de80631737>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['word'] = df_2020['word'].apply(lambda x: re.sub(r'[^\w\sㄱ-ㅎㅏ-ㅣ가-힣]', '', str(x))) # 특수 기호 제거
# <ipython-input-42-e7de80631737>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['word'] = df_2020['word'].apply(lambda x: re.findall(r'\b[ㄱ-ㅎㅏ-ㅣ가-힣]{2,}\b', x)[0] if len(re.findall(r'\b[ㄱ-ㅎㅏ-ㅣ가-힣]{2,}\b', x)) > 0 else '') # 2글자 이상인 단어만 남기기
#           word   freq
# 0          아파트  41793
# ...

# %%
import re

# 문자열로 변환
df_2021['word'] = df_2021['word'].astype(str)

# 정규식을 이용하여 특수기호 제거 및 2글자 이상인 단어만 추출
df_2021['word'] = df_2021['word'].apply(lambda x: re.sub('[^ㄱ-ㅣ가-힣]', '',x))  # 특수기호 제거
df_2021 = df_2021[df_2021['word'].str.len() >= 2]  # 2글자 이상인 단어만 추출

df_2021

# 딕셔너리로 변환
# result_2020 = df_2020.set_index('word')['freq'].to_dict()
# result_2020
# Out:
#        word   freq
# 8       아파트  39374
# 11       으로  36486
# 13       서울  29831
# 17       했다  22240
# 18       가격  19266
# ...     ...    ...
# 54719    만원      1
# 54720    만원      1
# 54722    만원      1
# 54723  찰하면서      1
# 54729   기어이      1
#
# [39892 rows x 2 columns]

# %%
df_2021.reset_index(drop = True, inplace = True)

# %%
df_2020.head(10)
# Out:
#   word   freq
# 0   으로  38660
# 1   했다  23949
# 2   가격  20376
# 3   에서  19555
# 4   상승  18281
# 5   거래  17531
# 6   주택  15594
# 7  부동산  14820
# 8   지역  14385
# 9   있다  13915

# %%
df_2021[df_2021['word']=='아파트']
# Out:
#      word   freq
# 0     아파트  39374
# 6672  아파트     16

# %%
df_2021.drop([0, 10185], inplace = True)

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34690 entries, 0 to 34689
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   word    34690 non-null  object
#  1   freq    34690 non-null  object
# dtypes: object(2)
# memory usage: 542.2+ KB

# %%
df_2020['freq'] = df_2020['freq'].astype(int)

# %%
df_2021 = pd.DataFrame(df_2021.groupby(['word'])['freq'].sum()).reset_index()
# temp[ temp['word']=='아파트']
df_2021
# Out:
#       word  freq
# 0       ㄱㅓ     1
# 1       ㅅㅅ     1
# 2       ㅇㅣ     1
# 3       ㅎㅎ     5
# 4      ㅎㅎㅎ     2
# ...    ...   ...
# 36429  힘써야     3
# 36430  힘쓰고     2
# 36431  힘주어     1
# 36432   힘찬     3
# 36433  힙입어     1
#
# [36434 rows x 2 columns]

# %%
df_2020['word']

# %%
df_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34690 entries, 0 to 34689
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   word    34690 non-null  object
#  1   freq    34690 non-null  object
# dtypes: object(2)
# memory usage: 542.2+ KB

# %%
dict(zip(df_2020['word'], df_2020['freq']))
# Out:
# {'아파트': '3',
#  '으로': '4',
#  '서울': '1',
#  '했다': '23949',
#  '가격': '20376',
#  '에서': '19555',
#  '상승': '18281',
#  '거래': '17531',
#  '주택': '15594',
#  '매매': '15454',
#  '부동산': '6',
#  '지역': '14385',
#  '있다': '13915',
#  '이다': '12082',
#  '단지': '10896',
#  '시장': '9453',
#  '전세': '9230',
#  '규제': '9158',
#  '강남': '1',
#  '정부': '8014',
#  '하는': '7257',
#  '기자': '76',
#  '됐다': '6680',
#  '집값': '6438',
#  '대책': '6435',
#  '보다': '6339',
#  '하락': '6305',
#  '하고': '6079',
#  '지난': '1',
#  '수요': '5877',
#  '이후': '5862',
#  '까지': '1',
#  '기록': '5765',
#  '대출': '5717',
#  '전용': '5638',
#  '따르면': '5522',
#  '분양': '1',
#  '올해': '1',
#  '수도권': '5150',
#  '평균': '1',
#  '있는': '5125',
#  '대비': '5069',
#  '매물': '5060',
#  '올랐다': '5010',
#  '기준': '4850',
#  '금지': '4842',
#  '승률': '4824',
#  '한국': '4790',
#  '상승세': '4759',
#  '경기': '4633',
#  '무단': '4529',
#  '셋값': '4484',
#  '지난달': '4472',
#  '경제': '4471',
#  '가구': '4455',
#  '지난해': '4442',
#  '배포': '4405',
#  '뉴스': '4361',
#  '최근': '1',
# ...

# %%
wordcloud = WordCloud(font_path=font_path, background_color='white', width=800, height=600, font_step=5, collocations=False, regexp="[\uAC00-\uD7A3]+").generate_from_frequencies(dict(zip(df_freq['word'], df_freq['freq'])))

# 워드 클라우드 출력
plt.figure(figsize=(10, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-86059560652b> in <cell line: 1>()
# ----> 1 df_word_count_2020_tuple = df_2020.to_tuple()
#       2 df_word_count_2020_tuple
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_tuple'

# %%
df_2021_dict = df_2021.set_index('word')['freq'].to_dict()
df_2021_dict
# Out:
# {'ㄱㅓ': 1,
#  'ㅅㅅ': 1,
#  'ㅇㅣ': 1,
#  'ㅎㅎ': 5,
#  'ㅎㅎㅎ': 2,
#  '가가': 991,
#  '가감': 2,
#  '가거나': 4,
#  '가거든요': 1,
#  '가게': 23,
#  '가겠다는': 3,
#  '가겠죠': 1,
#  '가겠지만': 2,
#  '가격': 19268,
#  '가격결정': 2,
#  '가격담합': 3,
#  '가격표': 10,
#  '가격하방리스크네이버에서': 1,
#  '가결': 4,
#  '가경동': 3,
#  '가계': 425,
#  '가계부채': 336,
#  '가계약': 14,
#  '가고': 54,
#  '가고요': 1,
#  '가고있다': 1,
#  '가공': 8,
#  '가관': 1,
#  '가구': 3900,
#  '가구가': 9,
#  '가구가량': 3,
#  '가구내': 1,
#  '가구대로': 1,
#  '가구대에': 1,
#  '가구도': 1,
#  '가구라': 1,
#  '가구로': 4,
#  '가구를': 21,
#  '가구수': 11,
#  '가구수는': 4,
#  '가구수를': 2,
#  '가구수에': 1,
#  '가구수와': 1,
#  '가구에': 11,
#  '가구에는': 1,
#  '가구에서': 2,
#  '가구였고': 1,
#  '가구였는데': 4,
#  '가구였다': 8,
#  '가구였던': 16,
#  '가구였으나': 2,
#  '가구였지만': 3,
#  '가구의': 11,
#  '가구이며': 1,
#  '가구인': 2,
#  '가구인데': 1,
#  '가구인데다': 1,
#  '가구주': 10,
#  '가급적': 11,
#  '가기': 26,
#  '가긴': 1,
#  '가까스로': 3,
#  '가까우며': 1,
#  '가까우면': 30,
#  '가까우면서': 1,
#  '가까우면서도': 1,
#  '가까운': 236,
#  '가까운데': 1,
#  '가까운데다가': 1,
#  '가까울': 12,
#  '가까울수록': 507,
# ...

# %%
df_2021_dict['아파트']
# Out:
# 39390

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_2021_dict)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
df_total_count_2021 = df_total_count_2021.sort_values(by = 'count', ascending=False)
df_total_count_2021['count'] = df_total_count_2021['count'].astype(int)
df_total_count_2021.reset_index(drop = True, inplace = True)
df_total_count_2021.head(30)
# Out:
#    word  count
# 0   아파트   4074
# 1     서   1309
# 2     울   1288
# 3     값   1230
# 4    서울   1160
# 5     억    807
# 6    매매    683
# 7    상승    642
# 8    거래    571
# 9     가    504
# 10    전    468
# 11    에    457
# 12    월    455
# 13   만에    439
# 14   하락    429
# 15    도    427
# 16   매수    420
# 17  수도권    410
# 18   최고    395
# 19  부동산    374
# 20    년    372
# 21    매    370
# 22   집값    365
# 23    폭    337
# 24   평균    336
# 25    상    327
# 26    주    315
# 27   가격    307
# 28   심리    298
# 29    은    293

# %%
df_filtered_2021 = df_total_count_2021.loc[df_total_count_2021['word'].str.len() >= 2]
df_filtered_2021.reset_index(drop = True, inplace = True)
df_filtered_2021.head()
# Out:
#   word  count
# 0  아파트   4074
# 1   서울   1160
# 2   매매    683
# 3   상승    642
# 4   거래    571

# %%
df_filtered_2021_dict = df_filtered_2021.set_index('word')['count'].to_dict()

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_2020_dict)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
df_filtered_2021_drop = df_filtered_2021.drop(index = [0, 1, 2])
df_filtered_2021_drop.reset_index(drop = True, inplace = True)
df_filtered_2021_drop.head(10)
# Out:
#   word  count
# 0   상승    642
# 1   거래    571
# 2   만에    439
# 3   하락    429
# 4   매수    420
# 5  수도권    410
# 6   최고    395
# 7  부동산    374
# 8   집값    365
# 9   평균    336

# %%
df_filtered_2021_drop_dict = df_filtered_2021_drop.set_index('word')['count'].to_dict()

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_filtered_2021_drop_dict)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
len(df_total_count_2020['word'])
# Out:
# 6647

# %%
df_word_count_2020_dict = df_word_count_2020.set_index('word')['count'].to_dict()

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_word_count_2020_dict)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
df_word_count_2020_drop = df_word_count_2020.drop(index = [0, 1, 4])
df_word_count_2020_drop.reset_index(drop = True, inplace = True)
df_word_count_2020_drop.head(10)
# Out:
#   word  count
# 0    값   1099
# 1    억    965
# 2   상승    866
# 3   강남    641
# 4   전세    567
# 5    주    500
# 6   집값    497
# 7   오르    413
# 8  부동산    399
# 9   거래    370

# %%
df_word_count_2020_dict2 = df_word_count_2020_drop.set_index('word')['count'].to_dict()

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color='white', font_path = "NanumBarunGothic")
cloud = wc.generate_from_frequencies(df_word_count_2020_dict2)
plt.imshow(cloud)
plt.axis('off')
plt.show()

# %%
# 3글자 이상도 가져 오게
df = pd.read_excel("/content/전체언론사 단어 빈도수 평균.xlsx")

df['two_word'] = df['word'].apply(lambda x: x[:3] if len(x) > 1 else None)

df = df.dropna(subset=['two_word'])

df = df[['two_word',"count"]]

# %%
df_1 = pd.DataFrame({'quarter':['2018-1q', '2018-2q', '2018-3q', '2018-4q', '2019-1q', '2019-2q'], 'price': [65, 73, 71, 78, 71, 84]}, index=list(range(6)))
df_1
# Out:
#    quarter  price
# 0  2018-1q     65
# 1  2018-2q     73
# 2  2018-3q     71
# 3  2018-4q     78
# 4  2019-1q     71
# 5  2019-2q     84

# %%
df_2 = pd.DataFrame({'quarter':['2018-1q', '2018-2q', '2018-3q', '2018-4q', '2019-1q', '2019-2q'], 'apt': [7000, 12873, 10094, 8705, 13500, 14397]}, index=list(range(6)))
df_2
# Out:
#    quarter    apt
# 0  2018-1q   7000
# 1  2018-2q  12873
# 2  2018-3q  10094
# 3  2018-4q   8705
# 4  2019-1q  13500
# 5  2019-2q  14397

# %%
df_final = pd.concat([df_1, df_2['apt']], axis = 1)
df_final
# Out:
#    quarter  price    apt
# 0  2018-1q     65   7000
# 1  2018-2q     73  12873
# 2  2018-3q     71  10094
# 3  2018-4q     78   8705
# 4  2019-1q     71  13500
# 5  2019-2q     84  14397

# %%
df_people = pd.read_excel('/content/부동산심리지수_각분기별_평균값.xlsx', index_col = None)
df_people
# Out:
#          date        mean
# 0  2018-01-01  123.133333
# 1  2018-04-01  108.133333
# 2  2018-07-01  121.866667
# 3  2018-10-01  105.166667
# 4  2019-01-01   93.266667
# 5  2019-04-01  100.633333
# 6  2019-07-01  120.033333
# 7  2019-10-01  128.633333
# 8  2020-01-01  115.466667
# 9  2020-04-01  115.533333
# 10 2020-07-01  132.866667
# 11 2020-10-01  131.866667
# 12 2021-01-01  123.466667
# 13 2021-04-01  123.033333
# 14 2021-07-01  131.033333
# 15 2021-10-01  110.500000
# 16 2022-01-01  103.000000
# 17 2022-04-01  107.066667
# 18 2022-07-01   89.933333
# 19 2022-10-01   76.333333

# %%
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    20 non-null     datetime64[ns]
#  1   mean    20 non-null     float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 448.0 bytes

# %%
df_people.columns
# Out:
# Index(['date', 'mean'], dtype='object')

# %%
df_people['date'] = df_people['date'].dt.strftime('%Y-%m')
df_people
# Out:
#        date        mean
# 0   2018-01  123.133333
# 1   2018-04  108.133333
# 2   2018-07  121.866667
# 3   2018-10  105.166667
# 4   2019-01   93.266667
# 5   2019-04  100.633333
# 6   2019-07  120.033333
# 7   2019-10  128.633333
# 8   2020-01  115.466667
# 9   2020-04  115.533333
# 10  2020-07  132.866667
# 11  2020-10  131.866667
# 12  2021-01  123.466667
# 13  2021-04  123.033333
# 14  2021-07  131.033333
# 15  2021-10  110.500000
# 16  2022-01  103.000000
# 17  2022-04  107.066667
# 18  2022-07   89.933333
# 19  2022-10   76.333333

# %%
df_people.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    20 non-null     object
#  1   mean    20 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 448.0+ bytes

# %%
df_people['date'][0][-2:]
# Out:
# '01'

# %%
change = []
for i in range(len(df_people['date'])):
  if df_people['date'][i][-2:] == '01':
    change.append(df_people['date'][i][:4] + ' 1분기')
  elif df_people['date'][i][-2:] == '04':
    change.append(df_people['date'][i][:4] + ' 2분기')
  elif df_people['date'][i][-2:] == '07':
    change.append(df_people['date'][i][:4] + ' 3분기')
  else:
    change.append(df_people['date'][i][:4] + ' 4분기')

# %%
change
# Out:
# ['2018 1분기',
#  '2018 2분기',
#  '2018 3분기',
#  '2018 4분기',
#  '2019 1분기',
#  '2019 2분기',
#  '2019 3분기',
#  '2019 4분기',
#  '2020 1분기',
#  '2020 2분기',
#  '2020 3분기',
#  '2020 4분기',
#  '2021 1분기',
#  '2021 2분기',
#  '2021 3분기',
#  '2021 4분기',
#  '2022 1분기',
#  '2022 2분기',
#  '2022 3분기',
#  '2022 4분기']

# %%
df_people['date'] = change
df_people
# Out:
#         date        mean
# 0   2018 1분기  123.133333
# 1   2018 2분기  108.133333
# 2   2018 3분기  121.866667
# 3   2018 4분기  105.166667
# 4   2019 1분기   93.266667
# 5   2019 2분기  100.633333
# 6   2019 3분기  120.033333
# 7   2019 4분기  128.633333
# 8   2020 1분기  115.466667
# 9   2020 2분기  115.533333
# 10  2020 3분기  132.866667
# 11  2020 4분기  131.866667
# 12  2021 1분기  123.466667
# 13  2021 2분기  123.033333
# 14  2021 3분기  131.033333
# 15  2021 4분기  110.500000
# 16  2022 1분기  103.000000
# 17  2022 2분기  107.066667
# 18  2022 3분기   89.933333
# 19  2022 4분기   76.333333

# %%
df_count = pd.read_excel('/content/2018 ~ 2022 분기별 합.xlsx', index_col = None)
df_count = df_count.rename(columns = {'Unnamed: 0': 'date'})
df_count
# Out:
#         date     서울
# 0   2018 1분기  54190
# 1   2018 2분기  31455
# 2   2018 3분기  44394
# 3   2018 4분기  31047
# 4   2019 1분기  18089
# 5   2019 2분기  24758
# 6   2019 3분기  39040
# 7   2019 4분기  47723
# 8   2020 1분기  49581
# 9   2020 2분기  32860
# 10  2020 3분기  49522
# 11  2020 4분기  34884
# 12  2021 1분기  31144
# 13  2021 2분기  28558
# 14  2021 3분기  20262
# 15  2021 4분기  13684
# 16  2022 1분기  11958
# 17  2022 2분기  12511
# 18  2022 3분기   9163
# 19  2022 4분기   7575

# %%
df_final = pd.concat([df_count, df_people['mean']], axis = 1)
df_final.head()
# Out:
#        date     서울        mean
# 0  2018 1분기  54190  123.133333
# 1  2018 2분기  31455  108.133333
# 2  2018 3분기  44394  121.866667
# 3  2018 4분기  31047  105.166667
# 4  2019 1분기  18089   93.266667

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(10, 5))

# 왼쪽 y축 설정
ax1.set_ylabel('거래량')
ax1.plot(df_final['date'], df_final['서울'], label='거래량', color='blue')

# 오른쪽 y축 설정
ax2 = ax1.twinx()
ax2.set_ylabel('부동산심리지수')
ax2.plot(df_final['date'], df_final['mean'], label='부동산심리지수', color='red')

# 그래프 타이틀 및 라벨 설정
ax1.set_xlabel('기간')
ax1.set_xticklabels(df_final['date'], rotation=90)
plt.title('2018 ~ 2022 서울 분기별 아파트 매매 거래량과 부동산심리지수', fontsize=15)

# 범례 추가
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines1 + lines2, labels1 + labels2, loc='upper right')

plt.show()
# Out:
# <ipython-input-19-bdf0ce406dd9>:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(df_final['date'], rotation=90)

# %%
df_simni = pd.read_excel('/content/부동산시장_소비심리지수_부동산원.xlsx', index_col = None)
df_simni.drop(0, inplace = True)
df_simni.drop('전국', axis = 1, inplace = True)
df_simni.columns = ['시점', '서울 심리']
df_simni.reset_index(drop = True, inplace = True)
df_simni.head()
# Out:
#         시점  서울 심리
# 0  2018.01  126.8
# 1  2018.02  126.3
# 2  2018.03  116.3
# 3  2018.04  108.3
# 4  2018.05  109.8

# %%
temp = []
for mon in df_simni['시점']:
  temp.append(mon[:4] + '년 ' + mon[-2:] + '월')

# %%
df_simni['시점'] = temp
df_simni.head()
# Out:
#           시점  서울 심리
# 0  2018년 01월  126.8
# 1  2018년 02월  126.3
# 2  2018년 03월  116.3
# 3  2018년 04월  108.3
# 4  2018년 05월  109.8

# %%
df_deal = pd.read_excel('/content/월별_아파트거래_부동산원(수정본).xlsx', index_col = None)
df_deal.drop(columns = 'Unnamed: 1', inplace = True)
df_deal.columns = ['시점', '서울 거래량']
# df_deal.rename(columns = {'지 역': '시점'}, inplace = True)
df_deal.head(10)
# Out:
#           시점  서울 거래량
# 0  2018년 01월   18212
# 1  2018년 02월   15305
# 2  2018년 03월   20673
# 3  2018년 04월   10130
# 4  2018년 05월   12312
# 5  2018년 06월    9013
# 6  2018년 07월   13648
# 7  2018년 08월   13182
# 8  2018년 09월   17564
# 9  2018년 10월   16609

# %%
df_concat = pd.concat([df_simni, df_deal['서울 거래량']], axis = 1)
df_concat.head()
# Out:
#           시점  서울 심리  서울 거래량
# 0  2018년 01월  126.8   18212
# 1  2018년 02월  126.3   15305
# 2  2018년 03월  116.3   20673
# 3  2018년 04월  108.3   10130
# 4  2018년 05월  109.8   12312

# %%
df_concat['서울 심리'] = df_concat['서울 심리'].astype(float)
df_concat['서울 거래량'] = df_concat['서울 거래량'].astype(float)
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시점      60 non-null     object
#  1   서울 심리   60 non-null     float64
#  2   서울 거래량  60 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.5+ KB

# %%
# 산점도 그리기
plt.scatter(df_concat['서울 심리'], df_concat['서울 거래량'])

# x축, y축 라벨 지정
plt.xlabel('거래량')
plt.ylabel('부동산심리지수')

# 그래프 제목 지정
plt.title('2018 ~ 2022 서울 월별 아파트 매매 거래량과 부동산심리지수')

# 그래프 보여주기
plt.show()

# %%
# 산점도 그리기
plt.scatter(df_concat['서울 거래량'], df_concat['서울 심리'])

# x축, y축 라벨 지정
plt.xlabel('부동산심리지수')
plt.ylabel('거래량')

# 그래프 제목 지정
plt.title('2018 ~ 2022 서울 월별 아파트 부동산심리지수와 매매 거래량')

# 그래프 보여주기
plt.show()

# %%
sns.regplot(data=df_concat, x = '서울 거래량', y = '서울 심리')
plt.xlabel('거래량')
plt.ylabel('부동산심리지수')
plt.title('2018 ~ 2022 서울 월별 아파트 매매 거래량과 부동산심리지수')
plt.show()

# %%
sns.regplot(data=df_concat, x = '서울 심리', y = '서울 거래량')
plt.xlabel('소비심리지수')
plt.ylabel('매매 건수')
plt.title('월별 아파트 소비심리지수와 매매 건수')
plt.show()

# %%
sns.jointplot(data=df_concat, x = '서울 거래량', y = '서울 심리')
plt.xlabel('거래량')
plt.ylabel('부동산심리지수')
plt.suptitle('2018 ~ 2022 서울 월별 아파트 매매 거래량과 부동산심리지수', y=1.02)
plt.show()

# %%
sns.jointplot(data=df_concat, x = '서울 심리', y = '서울 거래량')
plt.xlabel('부동산심리지수')
plt.ylabel('거래량')
plt.suptitle('2018 ~ 2022 서울 월별 아파트 부동산심리지수와 매매 거래량', y=1.02)
plt.show()

# %%
df_final.corr()
# Out:
# <ipython-input-33-dcfd88b6da59>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_final.corr()
#           price       apt
# price  1.000000  0.562392
# apt    0.562392  1.000000

# %%
import seaborn as sns

# %%
# 그래프 그리기
fig, ax1 = plt.subplots(figsize=(10, 6))
sns.barplot(data=df_final, x='quarter', y='price', ax=ax1, color='blue')
ax2 = ax1.twinx()
sns.barplot(data=df_final, x='quarter', y='apt', ax=ax2, color='red')

# 범례 추가
ax1.set_xlabel('Quarter')
ax1.set_ylabel('Price', color='blue')
ax2.set_ylabel('APT', color='red')
ax2.tick_params(axis='y', labelcolor='red')

leg1 = ax1.legend(loc='upper left', bbox_to_anchor=(1.01, 1))
leg2 = ax2.legend(loc='upper right', bbox_to_anchor=(1.01, 0.9))

plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 그래프 크기 설정
plt.figure(figsize=(10, 5))

# 왼쪽 y축에 대한 그래프 생성
ax1 = sns.barplot(data=df_final, x='quarter', y='apt', color='red')

# 오른쪽 y축에 대한 그래프 생성
ax2 = ax1.twinx()
ax2 = sns.barplot(data=df_final, x='quarter', y='price', color='blue', alpha=0.5)

# 왼쪽 y축 레이블과 타이틀 설정
ax1.set_ylabel('APT')
ax1.set_title('APT and Price by Quarter')

# 오른쪽 y축 레이블 설정
ax2.set_ylabel('Price')

plt.show()

# %%
# 그래프 그리기
sns.set_style('whitegrid')
g = sns.catplot(x='quarter', y='price', data=df_final, kind='bar', color='skyblue', alpha=.7)
g2 = sns.catplot(x='quarter', y='apt', data=df_final, kind='bar', color='red', alpha=.7)
plt.close(g2.fig)  # g2 plot을 닫습니다.

# 범례 추가
plt.subplots_adjust(top=0.8)
g.fig.suptitle('Price and APT by Quarter', fontsize=16)
g.ax.set_ylabel('Price', fontsize=14, color='skyblue')
g2.ax.set_ylabel('APT', fontsize=14, color='red')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))
g1 = sns.barplot(data=df_final, x='quarter', y='price', ax=ax)
ax2 = ax.twinx()
g2 = sns.lineplot(data=df_final, x='quarter', y='apt', ax=ax2, color='r')

# Add legend
lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc='best')

plt.show()

# %%
plt.figure(figsize = (10, 5))
sns.heatmap(df_final.corr(),
            annot = True, # 값이 표시
            fmt = '.1f', # 값을 정수형으로
            cmap = 'YlGnBu', # 컬러맵
            linewidth = .5 # 구분선
            )
plt.show()
# Out:
# <ipython-input-37-94e4358eb073>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df_final.corr(),

# %%
df_final.describe()
# Out:
#            price           apt
# count   6.000000      6.000000
# mean   73.666667  11094.833333
# std     6.562520   2943.862729
# min    65.000000   7000.000000
# 25%    71.000000   9052.250000
# 50%    72.000000  11483.500000
# 75%    76.750000  13343.250000
# max    84.000000  14397.000000

# %%
# 산점도 그리기
plt.scatter(df_final['price'], df_final['apt'])

# x축, y축 라벨 지정
plt.xlabel('price')
plt.ylabel('apt')

# 그래프 제목 지정
plt.title('price-apt')

# 그래프 보여주기
plt.show()
